# %%
import pandas
df = pandas.read_csv("static/month_fatals.csv")

# %%
df
# Out:
#     Unnamed: 0  MONTH  FATALS  count
# 0            0      1       1   1158
# 1            1      1       2     53
# 2            2      1       3      5
# 3            3      2       1    869
# 4            4      2       2     45
# 5            5      2       3      7
# 6            6      2       4      1
# 7            7      2       6      1
# 8            8      3       1   1116
# 9            9      3       2     47
# 10          10      3       3      8
# 11          11      3       4      2
# 12          12      4       1   1127
# 13          13      4       2     57
# 14          14      4       3     11
# 15          15      4       4      2
# 16          16      4       5      1
# 17          17      5       1   1286
# 18          18      5       2     74
# 19          19      5       3     10
# 20          20      5       5      1
# 21          21      6       1   1260
# 22          22      6       2     72
# 23          23      6       3      8
# ...

# %%
df
df.groupby('MONTH').sum().to_csv("month_fatals.csv")
